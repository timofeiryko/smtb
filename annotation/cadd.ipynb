# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cadd_df = pd.read_csv('/home/projects/genomics/CADD.csv')
cadd_df.head()
# Out:
#           rs_id  cadd_cleaned
# 0  rs1381099827          28.2
# 1  rs1381099827          28.2
# 2  rs1381099827          28.2
# 3  rs1381099827          28.2
# 4  rs1381099827          28.2

# %%
sd2_df = pd.read_csv('/home/projects/genomics/smtb/preprocessing/SD2.csv')
sd2_df
# Out:
#         Gene                               Trait  \
# 0      ACAP3       6mm weak meridian left (5097)
# 1       GNB1       Eosinophil percentage (30210)
# 2       GNB1       Eosinophil percentage (30210)
# 3       GNB1       Neutrophil percentage (30200)
# 4       GNB1       Neutrophil percentage (30200)
# ...      ...                                 ...
# 8860  ATP11C             Total bilirubin (30840)
# 8861  ATP11C  Glycated haemoglobin HbA1c (30750)
# 8862  ATP11C  Glycated haemoglobin HbA1c (30750)
# 8863  ATP11C            Direct bilirubin (30660)
# 8864   MECP2    Leg fat percentage right (23111)
#
#                                       Trait description Trait type  \
# 0     This is the weak meridian of keratometry resul...         QT
# 1     Result of "Eosinophils Percentage" assay, perf...         QT
# 2     Result of "Eosinophils Percentage" assay, perf...         QT
# 3     Result of "Neutrophils Percentage" assay, perf...         QT
# ...

# %%
new_found_snps = pd.read_csv('/home/projects/genomics/stats_results/significant_snps_summary_stats.csv', index_col=0)
new_found_snps
# Out:
#             chrom        pos             Gene  SYMBOL             ENSP  \
# Unnamed: 0
# 2604            5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676
# 3673            7  142040846  ENSG00000257335    MGAM  ENSP00000417515
# 5040           12   49005349  ENSG00000181929  PRKAG1  ENSP00000447433
# 5201           11  102949141  ENSG00000137745   MMP13  ENSP00000260302
# 5294           16   57683996  ENSG00000182885  ADGRG3  ENSP00000332900
# ...           ...        ...              ...     ...              ...
# 544             1  155291845  ENSG00000143627    PKLR  ENSP00000339933
# 548             1  155291918  ENSG00000143627    PKLR  ENSP00000339933
# 553             1  155294329  ENSG00000143627    PKLR  ENSP00000339933
# 4182            9   93110709  ENSG00000165233  CARD19  ENSP00000364613
# 4621           10   79353707  ENSG00000108179    PPIF  ENSP00000225174
#
#            Amino_acids aa_ensp                     file_name          rsid  \
# Unnamed: 0
# ...

# %%
old_df = sd2_df[sd2_df['P-value<2.18e-11 after controlling for GWAS signals?'] == 'Yes']

# %%
sd2_df.columns
# Out:
# Index(['Gene', 'Trait', 'Trait description', 'Trait type', 'Marker', 'Chr',
#        'Position', 'Reference allele', 'Effect allele', 'Marker type',
#        'Variant effect on protein sequence', 'Effect (95% CI)', 'P-value',
#        'Effect direction', 'N cases with 0|1|2 copies of effect allele',
#        'N controls with 0|1|2 copies of effect allele',
#        'Effect allele frequency', 'Minor allele count',
#        'Most significant trait-variant pair for this gene?',
#        'Most significant variant for this gene-trait pair?',
#        'Effect after controlling for GWAS signals (95% CI)',
#        'P-value after controlling for GWAS signals',
#        'P-value<2.18e-11 after controlling for GWAS signals?',
#        'N variants included in the burden test',
#        'N variants (i) included in the burden test; and (ii) tested individually for association with the trait',
# ...

# %%
old_df_all_info = pd.read_csv('/home/projects/genomics/stats_results/unique_mutations_in_sstats_with_all_info.csv', index_col=0)
old_df_all_info
# Out:
#             chrom       pos             Gene  SYMBOL             ENSP  \
# Unnamed: 0
# 0               1    963198  ENSG00000187961  KLHL17  ENSP00000343930
# 1               1    963963  ENSG00000187961  KLHL17  ENSP00000343930
# 2               1    963993  ENSG00000187961  KLHL17  ENSP00000343930
# 4               1    963994  ENSG00000187961  KLHL17  ENSP00000343930
# 5               1    964386  ENSG00000187961  KLHL17  ENSP00000343930
# ...           ...       ...              ...     ...              ...
# 8238           20  36927220  ENSG00000101347  SAMHD1  ENSP00000493536
# 8641           22  42067800  ENSG00000198951    NAGA  ENSP00000379680
# 3314            7   2250933  ENSG00000106268   NUDT1  ENSP00000349148
# 8028           19  45368656  ENSG00000104884   ERCC2  ENSP00000375809
# 8286           20  38151019  ENSG00000198959    TGM2  ENSP00000355330
#
#            Amino_acids aa_ensp                     file_name          rsid  \
# Unnamed: 0
# ...

# %%
old_df_all_info[old_df_all_info.p_value < 5e-8]
# Out:
#             chrom       pos             Gene  SYMBOL             ENSP  \
# Unnamed: 0
# 0               1    963198  ENSG00000187961  KLHL17  ENSP00000343930
# 1               1    963963  ENSG00000187961  KLHL17  ENSP00000343930
# 2               1    963993  ENSG00000187961  KLHL17  ENSP00000343930
# 4               1    963994  ENSG00000187961  KLHL17  ENSP00000343930
# 5               1    964386  ENSG00000187961  KLHL17  ENSP00000343930
# ...           ...       ...              ...     ...              ...
# 8238           20  36927220  ENSG00000101347  SAMHD1  ENSP00000493536
# 8641           22  42067800  ENSG00000198951    NAGA  ENSP00000379680
# 3314            7   2250933  ENSG00000106268   NUDT1  ENSP00000349148
# 8028           19  45368656  ENSG00000104884   ERCC2  ENSP00000375809
# 8286           20  38151019  ENSG00000198959    TGM2  ENSP00000355330
#
#            Amino_acids aa_ensp                     file_name          rsid  \
# Unnamed: 0
# ...

# %%
old_traits = old_df.Trait.unique()

# %%
subset_df = pd.read_csv('/home/projects/genomics/stats_results/significant_snps_and_disease_names.csv', index_col=0)
subset_df
# Out:
#      chrom        pos             Gene  SYMBOL             ENSP Amino_acids  \
# 0        5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 1        7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 2       12   49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 3       11  102949141  ENSG00000137745   MMP13  ENSP00000260302         R/H
# 4       16   57683996  ENSG00000182885  ADGRG3  ENSP00000332900         V/L
# ..     ...        ...              ...     ...              ...         ...
# 568      1  155291845  ENSG00000143627    PKLR  ENSP00000339933         Q/R
# 569      1  155291918  ENSG00000143627    PKLR  ENSP00000339933         W/R
# 570      1  155294329  ENSG00000143627    PKLR  ENSP00000339933         A/G
# 571      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 572     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
#
# ...

# %%
subset_df.human_disease.unique().size
# Out:
# 396

# %%
new_traits = subset_df.human_disease.unique

# %%
prev_found_snps = subset_df[subset_df.p_value < 5e-8].rsid.unique()

# %%
cadd_df.rename(columns={'rs_id': 'rsid'}, inplace=True)
cadd_df.head()
# Out:
#            rsid  cadd_cleaned
# 0  rs1381099827          28.2
# 1  rs1381099827          28.2
# 2  rs1381099827          28.2
# 3  rs1381099827          28.2
# 4  rs1381099827          28.2

# %%
new_found_snps = subset_df.rsid.unique()

# %%
subset_df
# Out:
#      chrom        pos             Gene  SYMBOL             ENSP Amino_acids  \
# 0        5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 1        7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 2       12   49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 3       11  102949141  ENSG00000137745   MMP13  ENSP00000260302         R/H
# 4       16   57683996  ENSG00000182885  ADGRG3  ENSP00000332900         V/L
# ..     ...        ...              ...     ...              ...         ...
# 568      1  155291845  ENSG00000143627    PKLR  ENSP00000339933         Q/R
# 569      1  155291918  ENSG00000143627    PKLR  ENSP00000339933         W/R
# 570      1  155294329  ENSG00000143627    PKLR  ENSP00000339933         A/G
# 571      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 572     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
#
# ...

# %%
subset_df = subset_df.merge(cadd_df, on='rsid')

# %%
subset_df
# Out:
#       chrom        pos             Gene  SYMBOL             ENSP Amino_acids  \
# 0         5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 1         5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 2         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 3         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 4         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# ...     ...        ...              ...     ...              ...         ...
# 3134     20   63350897  ENSG00000101204  CHRNA4  ENSP00000359285         */Q
# 3135      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3136      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3137     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
# 3138     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
#
# ...

# %%
sns.barplot(data=subset_df, x=)

# %%
old_method = subset_df[subset_df.p_value < 5e-8].copy()
new_method = subset_df.copy()

# %%
old_method['method'] = 'old'
old_method
# Out:
#       chrom        pos             Gene   SYMBOL             ENSP Amino_acids  \
# 5        12   49005349  ENSG00000181929   PRKAG1  ENSP00000447433         S/T
# 6        12   49005349  ENSG00000181929   PRKAG1  ENSP00000447433         S/T
# 7        12   49005349  ENSG00000181929   PRKAG1  ENSP00000447433         S/T
# 8        12   49005349  ENSG00000181929   PRKAG1  ENSP00000447433         S/T
# 9        12   49005349  ENSG00000181929   PRKAG1  ENSP00000447433         S/T
# ...     ...        ...              ...      ...              ...         ...
# 2762      2  151366169  ENSG00000123610  TNFAIP6  ENSP00000243347         C/R
# 2846     17    7173803  ENSG00000141505    ASGR1  ENSP00000269299         */W
# 2847     17    7173803  ENSG00000141505    ASGR1  ENSP00000269299         */W
# 2848     17    7173803  ENSG00000141505    ASGR1  ENSP00000269299         */W
# 2849     17    7173803  ENSG00000141505    ASGR1  ENSP00000269299         */W
#
# ...

# %%
new_method['method'] = 'new'
new_method
# Out:
#       chrom        pos             Gene  SYMBOL             ENSP Amino_acids  \
# 0         5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 1         5  115237957  ENSG00000164219  PGGT1B  ENSP00000404676         I/T
# 2         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 3         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# 4         7  142040846  ENSG00000257335    MGAM  ENSP00000417515         N/S
# ...     ...        ...              ...     ...              ...         ...
# 3134     20   63350897  ENSG00000101204  CHRNA4  ENSP00000359285         */Q
# 3135      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3136      9   93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3137     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
# 3138     10   79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
#
# ...

# %%
to_compare = pd.concat([old_method, new_method])
to_compare
# Out:
#       chrom       pos             Gene  SYMBOL             ENSP Amino_acids  \
# 5        12  49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 6        12  49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 7        12  49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 8        12  49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# 9        12  49005349  ENSG00000181929  PRKAG1  ENSP00000447433         S/T
# ...     ...       ...              ...     ...              ...         ...
# 3134     20  63350897  ENSG00000101204  CHRNA4  ENSP00000359285         */Q
# 3135      9  93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3136      9  93110709  ENSG00000165233  CARD19  ENSP00000364613         C/R
# 3137     10  79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
# 3138     10  79353707  ENSG00000108179    PPIF  ENSP00000225174         C/W
#
# ...

# %%
sns.barplot(data=to_compare, x='method', y='cadd_cleaned')
bars = plt.gca()[0]
plt.bar_label(bars, to_compare.method)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/dreamtim/Desktop/Coding/smtb/cadd.ipynb Cell 25 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/dreamtim/Desktop/Coding/smtb/cadd.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> sns.barplot(data=to_compare, x='method', y='cadd_cleaned')
# ----> <a href='vscode-notebook-cell:/home/dreamtim/Desktop/Coding/smtb/cadd.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> bars = plt.gca()[0]
#       <a href='vscode-notebook-cell:/home/dreamtim/Desktop/Coding/smtb/cadd.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> plt.bar_label(bars, to_compare.method)
#       <a href='vscode-notebook-cell:/home/dreamtim/Desktop/Coding/smtb/cadd.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
plt.gca().
# Out:
# <AxesSubplot:>
